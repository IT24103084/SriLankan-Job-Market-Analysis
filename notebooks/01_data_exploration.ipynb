# %%
import pandas as pd

df = pd.read_csv("../data/processed/jobs_detailed.csv")

df.head()
# Out:
#                                 title                    company posted_date  \
# 0                 Accounts Executive   Avenierr Pharma (Pvt) Ltd  2026-06-26
# 1                         Proofreader         B.R. De Silva & Co  2026-06-26
# 2  Quality Manager - Offset Printing       Company Name Withheld  2026-06-26
# 3              Attorneys - At - Law                    Elite Law  2026-06-26
# 4                   Outlet Supervisor     Roots Global (Pvt) Ltd  2026-06-26
#
#                closing_date           city   region  \
# 0  2026-07-10T00:00:00+0530     Kalubowila  Western
# 1  2026-07-10T00:00:00+0530      Colombo 5  Western
# 2  2026-07-10T00:00:00+0530      Colombo 1  Western
# 3  2026-07-10T00:00:00+0530  Boralesgamuwa  Western
# 4  2026-07-10T00:00:00+0530      Colombo 1  Western
#
#                                                  url
# 0  https://www.topjobs.lk/employer/JobAdvertismen...
# 1  https://www.topjobs.lk/employer/JobAdvertismen...
# 2  https://www.topjobs.lk/employer/JobAdvertismen...
# 3  https://www.topjobs.lk/employer/JobAdvertismen...
# 4  https://www.topjobs.lk/employer/JobAdvertismen...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         20 non-null     str
#  1   company       20 non-null     str
#  2   posted_date   20 non-null     str
#  3   closing_date  20 non-null     str
#  4   city          20 non-null     str
#  5   region        20 non-null     str
#  6   url           20 non-null     str
# dtypes: str(7)
# memory usage: 1.2 KB

# %%
df.isnull().sum()
# Out:
# title           0
# company         0
# posted_date     0
# closing_date    0
# city            0
# region          0
# url             0
# dtype: int64

# %%
print("Total Jobs:", len(df))
# Out:
# Total Jobs: 20

# %%
df["city"].value_counts().head(10)
# Out:
# city
# Colombo 7        4
# Colombo 1        2
# Colombo 10       2
# Colombo 3        2
# Kalubowila       1
# Colombo 5        1
# Boralesgamuwa    1
# Ratmalana        1
# Ratnapura        1
# Colombo 8        1
# Name: count, dtype: int64

# %%
df["region"].value_counts()
# Out:
# region
# Western          18
# Sabaragamuwa      1
# North Central     1
# Name: count, dtype: int64

# %%
df["company"].value_counts().head(10)
# Out:
# company
# Company Name Withheld                            4
# The Institute of Chartered Accountants of SL     2
# Ladies' College                                  2
# Avenierr Pharma (Pvt) Ltd                        1
# B.R. De Silva & Co                               1
# Elite Law                                        1
# Roots Global (Pvt) Ltd                           1
# FLITS Vocational Training Institute              1
# Lyceum International School - Ratnapura          1
# Smart Wireless Engineering Networks (Pvt) Ltd    1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

top_companies = df["company"].value_counts().head(10)

plt.figure(figsize=(10,6))
top_companies.plot(kind="bar")
plt.title("Top Hiring Companies")
plt.ylabel("Number of Jobs")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
