# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/processed/jobs_detailed.csv")

# %%
df.head()
# Out:
#                                 title                    company posted_date  \
# 0                 Accounts Executive   Avenierr Pharma (Pvt) Ltd  2026-06-26
# 1                         Proofreader         B.R. De Silva & Co  2026-06-26
# 2  Quality Manager - Offset Printing       Company Name Withheld  2026-06-26
# 3              Attorneys - At - Law                    Elite Law  2026-06-26
# 4                   Outlet Supervisor     Roots Global (Pvt) Ltd  2026-06-26
#
#                closing_date           city   region    category  \
# 0  2026-07-10T00:00:00+0530     Kalubowila  Western   Executive
# 1  2026-07-10T00:00:00+0530      Colombo 5  Western       Other
# 2  2026-07-10T00:00:00+0530      Colombo 1  Western  Management
# 3  2026-07-10T00:00:00+0530  Boralesgamuwa  Western       Other
# 4  2026-07-10T00:00:00+0530      Colombo 1  Western       Other
#
#                                                  url
# 0  https://www.topjobs.lk/employer/JobAdvertismen...
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3439 entries, 0 to 3438
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         3439 non-null   str
#  1   company       3439 non-null   str
#  2   posted_date   3439 non-null   str
#  3   closing_date  3439 non-null   str
#  4   city          3404 non-null   str
#  5   region        3404 non-null   str
#  6   category      3439 non-null   str
#  7   url           3439 non-null   str
# dtypes: str(8)
# memory usage: 215.1 KB

# %%
df.isnull().sum()
# Out:
# title            0
# company          0
# posted_date      0
# closing_date     0
# city            35
# region          35
# category         0
# url              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()

# %%
df["title"] = df["title"].str.strip()
df["company"] = df["company"].str.strip()
df["city"] = df["city"].str.strip()
df["region"] = df["region"].str.strip()
df["category"] = df["category"].str.strip()

# %%
df["posted_date"] = pd.to_datetime(df["posted_date"])
df["closing_date"] = pd.to_datetime(df["closing_date"])

# %%
df.dtypes
# Out:
# title                                 str
# company                               str
# posted_date                datetime64[us]
# closing_date    datetime64[us, UTC+05:30]
# city                                  str
# region                                str
# category                              str
# url                                   str
# dtype: object

# %%
df["posted_date"] = pd.to_datetime(df["posted_date"])

df["closing_date"] = pd.to_datetime(df["closing_date"]).dt.tz_localize(None)

# %%
df["days_open"] = (
    df["closing_date"] - df["posted_date"]
).dt.days

# %%
df.head()
# Out:
#                                title                    company posted_date  \
# 0                 Accounts Executive  Avenierr Pharma (Pvt) Ltd  2026-06-26
# 1                        Proofreader         B.R. De Silva & Co  2026-06-26
# 2  Quality Manager - Offset Printing      Company Name Withheld  2026-06-26
# 3               Attorneys - At - Law                  Elite Law  2026-06-26
# 4                  Outlet Supervisor     Roots Global (Pvt) Ltd  2026-06-26
#
#   closing_date           city   region    category  \
# 0   2026-07-10     Kalubowila  Western   Executive
# 1   2026-07-10      Colombo 5  Western       Other
# 2   2026-07-10      Colombo 1  Western  Management
# 3   2026-07-10  Boralesgamuwa  Western       Other
# 4   2026-07-10      Colombo 1  Western       Other
#
#                                                  url  days_open
# 0  https://www.topjobs.lk/employer/JobAdvertismen...         14
# 1  https://www.topjobs.lk/employer/JobAdvertismen...         14
# ...

# %%
df.to_csv("../data/cleaned/jobs_cleaned.csv", index=False)
